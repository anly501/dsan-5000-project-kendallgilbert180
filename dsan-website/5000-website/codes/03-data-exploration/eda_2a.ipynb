# %% [markdown]
# # Data 2a Exploratory Data Analysis

# %% [markdown]
# ## Data Understanding
#
# I included this code because I want to show how important the ocean is in regards to tourism and being a summer activity. This data set collected from the State of New Yorks website gives information on the numbers of people who attended New York beaches from 2017 to 2022. This data set includes categorical and numerical data. This data will help me proove that the ocean brings a lot of people joy in the summertime and without clean oceans - these numbers would go down.

# %% [markdown]
# ## Descriptive Statistics

# %%
#| code-fold: true
import pandas as pd
pd.options.display.float_format = '{:.2f}'.format
data2a = pd.read_csv('/Users/kendallgilbert/dsan-5000-project-kendallgilbert180/dsan-website/5000-website/data/01-modified-data/cleandata2a.csv')
#Summary Statistics
data2a[["Attendance"]].describe()
# Out:
#        Attendance
# count     5051.00
# mean     15606.51
# std      47840.66
# min          0.00
# 25%        350.00
# 50%       1600.00
# 75%       7800.00
# max    1520000.00

# %% [markdown]
# On average, from the years 2017 - 2021 and the months May through September: 15,000 people went to the beach in the state of New York. Furthemore, the highest recorded attendance was 1,520,000 in Coney Island on July 4th, 2018. (Looking into this number)

# %%
#| code-fold: true
#Frequency Distribution
import matplotlib.pyplot as plt
import seaborn as sns
location_freq = data2a["Month"].value_counts()
print(location_freq)
plt.figure(figsize=(8, 6))
sns.barplot(x=location_freq.index, y=location_freq.values, palette="Set2")
plt.xlabel("Location")
plt.ylabel("Frequency")
plt.title("Frequency Distribution of Locations")
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()
# Out:
# Month
# July         1488
# August       1488
# June         1440
# September     364
# May           272
# Name: count, dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
#| code-fold: true
#Data Visualization
import matplotlib.pyplot as plt
average = data2a.groupby("Month")["Attendance"].mean().reset_index()
print(average)
# Create a bar chart
plt.figure(figsize=(8, 6))
plt.bar(average["Month"], average["Attendance"], color='#ADD8E6')
plt.xlabel("Month")
plt.ylabel("Average Attendance")
plt.title("Average Attendance by Month (2017 - 2021)")
plt.gca().get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
plt.xticks(rotation=45)
plt.show()
# Out:
#        Month  Attendance
# 0     August    14959.65
# 1       July    21816.85
# 2       June    11504.00
# 3        May     8720.81
# 4  September    14255.65

# %%
#| code-fold: true
plt.figure(figsize=(8, 6))
sns.pointplot(x="Month", y="Attendance", data=data2a, color='#ADD8E6')
plt.xlabel("Month")
plt.ylabel("Attendance")
plt.title("Attendance Variation by Month")
plt.gca().get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
plt.xticks(rotation=45)
plt.show()

# %%
#| code-fold: true
data2a["Date"] = pd.to_datetime(data2a["Date"])
data2a["Year"] = data2a["Date"].dt.year
yearly_sum = data2a.groupby("Year")["Attendance"].sum()
plt.figure(figsize=(8, 6))
plt.plot(yearly_sum.index, yearly_sum.values, marker='o', linestyle='-')
plt.xlabel("Year")
plt.ylabel("Sum of Attendance")
plt.title("Sum of Attendance Each Year")
plt.gca().get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
plt.grid(True)
plt.show()

# %% [markdown]
# ## Correlation Analysis

# %% [markdown]
# ## Outlier Detection
#
# - One year that seems to be an outlier is this data set is the year 2020. This makes sense because this is when COVID was at its peak.
# - Numbers are very high around the 4th of July

# %%
#| code-fold: true
data2a["Date"] = pd.to_datetime(data2a["Date"])
# Filter the DataFrame for Fourth of July (July 4th)
fourth_of_july_data = data2a[data2a["Date"].dt.month == 7]  # Filter for July
pd.options.display.float_format = '{:.2f}'.format
plt.figure(figsize=(8, 6))
plt.bar(fourth_of_july_data["Year"], fourth_of_july_data["Attendance"], color='#ADD8E6')
plt.xlabel("Beach")
plt.ylabel("Attendance")
plt.title("Attendance on July 4th for Each Beach")
plt.xticks(rotation=45)
plt.gca().get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
plt.show()

# %% [markdown]
# ## Methods and Findings
#
# Using this dataset, I was able to visualize how many people go to the beach. These numbers are very high and they are just for the state of New York. This dataset helps proove that people enjoy going to the beach, especially around holidays like fourth of July.
#
# A few key takeaways from the data visualizations:
#
# - People visit the beach the most in months June, July and August
# - Beach attendance is highest in July and specifically on the fourth
# - Beach attendance went down in 2020 as a result of Covid (an outlier)
#
# Overall, I am able to use this data to proove that a lot of people enjoy going to the beach.
